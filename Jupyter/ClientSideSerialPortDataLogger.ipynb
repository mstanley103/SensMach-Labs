# %%
from IPython.display import HTML, display
display(HTML(filename='./HTML/loggerV3.html'))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# 	<head>
# 		<meta charset="UTF-8">
# 		<title>Data Logger</title>
# 		<!-- Copyright 2020 by Michael Stanley -->
# 		<style>
# .hidden {
#   display: none;
# }
# h1 {
# 	 text-align: center
# }
#
# footer {
#   position: fixed;
#   left: 0;
#   bottom: 0;
#   width: 100%;
#   background-color: gray;
#   color: white;
#   text-align: center;
# }
#
# #notSupported {
#   background-color: red;
#   color: white;
#   padding: 1em;
# }
#
# #logger-controls {
# 	background: lime
# }
# #logger-console {
# 	background: silver
# 	height: 200px;
# }
#
# button {
# 	padding: .5em;
# 	margin: 0.5em;
# }
#
# #message-to-send {
# 	padding: .5em;
# 	margin: 0.5em;
# }
# #logEnable {
# 	padding: .5em;
# 	left-margin: 0.5em;
# 	right-margin: 0em;
# }
# label {
# 	padding: .5em;
# 	left-margin: 0em;
# 	right-margin: 0.5em;
# }
# select {
# 	padding: .5em;
# 	right-margin: 0.5em;
# }
# 		</style>
#
# 	</head>
# 	<body>
# 		<h1>Serial Port Data Logger</h1>
# ...

# %%
display(HTML(filename='./HTML/helpV3.html'))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<meta name="viewport" content="width=device-width, initial-scale=1.0">
# 	<title>Help</title>
# 	<link rel="stylesheet" href="style.css">
#     <script src="scripts/logger.js"></script>
# </head>
# <body>
#
# 	<h1>Serial Port Data Logger Help</h1>
# 	Serial Port Data Logger &copy; 2020 by <a href="mailto:Mike.Stanley@ieee.org">Michael Stanley</a><br>
# 	Licensed under the creative commons <a href="https://creativecommons.org/licenses/by-nc/4.0/">Attribution-NonCommercial 4.0 International (CC By-NC 4.0</a>
# 	license.
# 	<br>Please contact the author for commercial licensing terms.
# 	<br>Last revised: 26 August 2020
# 	<h2>Introduction</h2>
# 	This application is intended to enable you to capture sensor data from an embedded development board which connects
# 	to your PC via a serial port interface.  Unlike most data logger applications to date, this application runs completely in
# ...
